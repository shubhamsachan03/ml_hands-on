# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame({'yes':[50,21],'No':[10,12]},index=['prod A','prod B'])
# Out:
#         yes  No
# prod A   50  10
# prod B   21  12

# %%
pd.Series([1,2,3,4,5],index=['A','B','C','D','E'])
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
data=pd.read_csv("C:/Users/shubh/Revision/white_wine_data_1.csv")

# %%
data.shape
# Out:
# (4898, 12)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
a=data.loc[data["quality"]==6]
a.shape
# Out:
# (2198, 12)

# %%
data.quality
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
data['quality']
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
data['quality'][0]   # accesing 1st element of quality column
# Out:
# 6

# %% [markdown]
# # iloc

# %% [markdown]
# The first is index-based selection: selecting data based on its numerical position in the data. iloc follows this paradigm.

# %%
data.iloc[0]   #To select the first row of data in a DataFrame
# Out:
# fixed acidity             7.000
# volatile acidity          0.270
# citric acid               0.360
# residual sugar           20.700
# chlorides                 0.045
# free sulfur dioxide      45.000
# total sulfur dioxide    170.000
# density                   1.001
# pH                        3.000
# sulphates                 0.450
# alcohol                   8.800
# quality                   6.000
# Name: 0, dtype: float64

# %% [markdown]
# Both loc and iloc are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second.

# %%
data.iloc[0,0:10]
# Out:
# fixed acidity             7.000
# volatile acidity          0.270
# citric acid               0.360
# residual sugar           20.700
# chlorides                 0.045
# free sulfur dioxide      45.000
# total sulfur dioxide    170.000
# density                   1.001
# pH                        3.000
# sulphates                 0.450
# Name: 0, dtype: float64

# %%
data.iloc[:3,0]
# Out:
# 0    7.0
# 1    6.3
# 2    8.1
# Name: fixed acidity, dtype: float64

# %%
data.iloc[1:3,0]
# Out:
# 1    6.3
# 2    8.1
# Name: fixed acidity, dtype: float64

# %%
data.iloc[[0,1,2],0]
# Out:
# 0    7.0
# 1    6.3
# 2    8.1
# Name: fixed acidity, dtype: float64

# %%
data.iloc[-4:]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %% [markdown]
# # Loc

# %% [markdown]
# The second paradigm for attribute selection is the one followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters.

# %%
data.loc[0,'fixed acidity']
# Out:
# 7.0

# %%
data.loc[:,'fixed acidity':'chlorides']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0                 0              0.27         0.36            20.7      0.045
# 1                 0              0.30         0.34             1.6      0.049
# 2                 0              0.28         0.40             6.9      0.050
# 3                 0              0.23         0.32             8.5      0.058
# 4                 0              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893              0              0.21         0.29             1.6      0.039
# 4894              0              0.32         0.36             8.0      0.047
# 4895              0              0.24         0.19             1.2      0.041
# 4896              0              0.29         0.30             1.1      0.022
# 4897              0              0.21         0.38             0.8      0.020
#
# [4898 rows x 5 columns]

# %%
data.loc[:,['fixed acidity','volatile acidity','citric acid']]
# Out:
#       fixed acidity  volatile acidity  citric acid
# 0               7.0              0.27         0.36
# 1               6.3              0.30         0.34
# 2               8.1              0.28         0.40
# 3               7.2              0.23         0.32
# 4               7.2              0.23         0.32
# ...             ...               ...          ...
# 4893            6.2              0.21         0.29
# 4894            6.6              0.32         0.36
# 4895            6.5              0.24         0.19
# 4896            5.5              0.29         0.30
# 4897            6.0              0.21         0.38
#
# [4898 rows x 3 columns]

# %% [markdown]
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.

# %%
data.set_index("quality")
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 6                  7.0              0.27         0.36            20.7
# 6                  6.3              0.30         0.34             1.6
# 6                  8.1              0.28         0.40             6.9
# 6                  7.2              0.23         0.32             8.5
# 6                  7.2              0.23         0.32             8.5
# ...                ...               ...          ...             ...
# 6                  6.2              0.21         0.29             1.6
# 5                  6.6              0.32         0.36             8.0
# 6                  6.5              0.24         0.19             1.2
# 7                  5.5              0.29         0.30             1.1
# 6                  6.0              0.21         0.38             0.8
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# ...

# %%
data['fixed acidity']==7  # true/false
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# Name: fixed acidity, Length: 4898, dtype: bool

# %%
data.loc[(data['fixed acidity']==7) & (data['residual sugar']<5)]  # whole data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 37              7.0              0.33         0.32             1.2      0.053
# 62              7.0              0.47         0.07             1.1      0.035
# 77              7.0              0.32         0.34             1.3      0.042
# 117             7.0              0.14         0.40             1.7      0.035
# 238             7.0              0.26         0.59             1.4      0.037
# ...             ...               ...          ...             ...        ...
# 4698            7.0              0.27         0.74             1.3      0.173
# 4811            7.0              0.17         0.42             1.0      0.075
# 4821            7.0              0.24         0.47             1.3      0.043
# 4848            7.0              0.36         0.35             2.5      0.048
# 4850            7.0              0.36         0.35             2.5      0.048
#
# ...

# %%
data.loc[data['fixed acidity'].isin([7,6])]  # if categorical then within ''
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 7               7.0              0.27         0.36            20.7      0.045
# 25              7.0              0.25         0.32             9.0      0.046
# 27              7.0              0.28         0.39             8.7      0.051
# 37              7.0              0.33         0.32             1.2      0.053
# ...             ...               ...          ...             ...        ...
# 4859            6.0              0.43         0.34             7.6      0.045
# 4860            6.0              0.52         0.33             7.7      0.046
# 4864            6.0              0.41         0.23             1.1      0.066
# 4872            6.0              0.42         0.41            12.4      0.032
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.loc[data["fixed acidity"].notnull()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.loc[data["fixed acidity"].isnull()]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
data["fixed acidity"]=0

# %%
print(data["fixed acidity"])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4893    0
# 4894    0
# 4895    0
# 4896    0
# 4897    0
# Name: fixed acidity, Length: 4898, dtype: int64

# %%
data["fixed acidity"].describe()
# Out:
# count    4898.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: fixed acidity, dtype: float64

# %%
data["citric acid"].mean()
# Out:
# 0.33419150673743736

# %%
data.mean(axis=0)
# Out:
# fixed acidity             6.854788
# volatile acidity          0.278241
# citric acid               0.334192
# residual sugar            6.391415
# chlorides                 0.045772
# free sulfur dioxide      35.308085
# total sulfur dioxide    138.360657
# density                   0.994027
# pH                        3.188267
# sulphates                 0.489847
# alcohol                  10.514267
# quality                   5.877909
# dtype: float64

# %%
data["quality"].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
data["quality"].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
data.groupby('quality').quality.count()
# Out:
# quality
# 3      20
# 4     163
# 5    1457
# 6    2198
# 7     880
# 8     175
# 9       5
# Name: quality, dtype: int64

# %%
data.groupby('quality').quality.min()
# Out:
# quality
# 3    3
# 4    4
# 5    5
# 6    6
# 7    7
# 8    8
# 9    9
# Name: quality, dtype: int64

# %%
data_mean=data.quality.mean()
print(data_mean)
data.quality.map(lambda p:p -data_mean)
# Out:
# 5.87790935075541
# 0       0.122091
# 1       0.122091
# 2       0.122091
# 3       0.122091
# 4       0.122091
#           ...
# 4893    0.122091
# 4894   -0.877909
# 4895    0.122091
# 4896    1.122091
# 4897    0.122091
# Name: quality, Length: 4898, dtype: float64

# %%
data.quality.dtype  # dtype
# Out:
# dtype('int64')

# %%
data.dtypes   # dtypes
# Out:
# fixed acidity             int64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
data.quality.astype('float64')
# Out:
# 0       6.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       6.0
#        ...
# 4893    6.0
# 4894    5.0
# 4895    6.0
# 4896    7.0
# 4897    6.0
# Name: quality, Length: 4898, dtype: float64

# %%
miss=data.isnull().sum() #get the number of missing data points per column # no missing data so 0
miss
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
total_miss=miss.sum()
print(total_miss)
# Out:
# 0

# %%
 data.dropna()             #remove all the rows that contain a missing value
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0                 0              0.27         0.36            20.7      0.045
# 1                 0              0.30         0.34             1.6      0.049
# 2                 0              0.28         0.40             6.9      0.050
# 3                 0              0.23         0.32             8.5      0.058
# 4                 0              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893              0              0.21         0.29             1.6      0.039
# 4894              0              0.32         0.36             8.0      0.047
# 4895              0              0.24         0.19             1.2      0.041
# 4896              0              0.29         0.30             1.1      0.022
# 4897              0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.dropna(axis=1)  ## remove all columns with at least one missing value
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0                 0              0.27         0.36            20.7      0.045
# 1                 0              0.30         0.34             1.6      0.049
# 2                 0              0.28         0.40             6.9      0.050
# 3                 0              0.23         0.32             8.5      0.058
# 4                 0              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893              0              0.21         0.29             1.6      0.039
# 4894              0              0.32         0.36             8.0      0.047
# 4895              0              0.24         0.19             1.2      0.041
# 4896              0              0.29         0.30             1.1      0.022
# 4897              0              0.21         0.38             0.8      0.020
#
# ...

# %%
# replace all NA's with 0
data.fillna(0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0                 0              0.27         0.36            20.7      0.045
# 1                 0              0.30         0.34             1.6      0.049
# 2                 0              0.28         0.40             6.9      0.050
# 3                 0              0.23         0.32             8.5      0.058
# 4                 0              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893              0              0.21         0.29             1.6      0.039
# 4894              0              0.32         0.36             8.0      0.047
# 4895              0              0.24         0.19             1.2      0.041
# 4896              0              0.29         0.30             1.1      0.022
# 4897              0              0.21         0.38             0.8      0.020
#
# ...

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the remaining na's with 0
data.fillna(method='bfill', axis=0).fillna(0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0                 0              0.27         0.36            20.7      0.045
# 1                 0              0.30         0.34             1.6      0.049
# 2                 0              0.28         0.40             6.9      0.050
# 3                 0              0.23         0.32             8.5      0.058
# 4                 0              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893              0              0.21         0.29             1.6      0.039
# 4894              0              0.32         0.36             8.0      0.047
# 4895              0              0.24         0.19             1.2      0.041
# 4896              0              0.29         0.30             1.1      0.022
# 4897              0              0.21         0.38             0.8      0.020
#
# ...

# %%
indices = np.where([data['quality'] == 9])[1]  # to obtain where indices ==9
print(indices)
# Out:
# [ 774  820  827  876 1605]

# %%
data.loc[indices]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 774             9.1              0.27         0.45            10.6      0.035
# 820             6.6              0.36         0.29             1.6      0.021
# 827             7.4              0.24         0.36             2.0      0.031
# 876             6.9              0.36         0.34             4.2      0.018
# 1605            7.1              0.26         0.49             2.2      0.032
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 774                  28.0                 124.0  0.99700  3.20       0.46
# 820                  24.0                  85.0  0.98965  3.41       0.61
# 827                  27.0                 139.0  0.99055  3.28       0.48
# 876                  57.0                 119.0  0.98980  3.28       0.36
# 1605                 31.0                 113.0  0.99030  3.37       0.42
#
#       alcohol  quality
# 774      10.4        9
# ...

# %%
earthquakes.loc[20650, "Date"] = "03/13/2011"   # ex to make 20650 index of date column =given date

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report ,f1_score# for model evaluation metrics
from sklearn.svm import SVC 
from sklearn.ensemble import GradientBoostingClassifier

# %%
X=data.iloc[:,0:11]
y=data.iloc[:,11]

# %%
train_x, test_x,train_y,test_y = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
clf = DecisionTreeClassifier(
            criterion = "entropy", random_state = 100,
            max_depth = 3, min_samples_leaf = 5)
clf.fit(train_x, train_y)
 
# performing predictions on the test dataset
y_pred = clf.predict(test_x)
y_pred_tr=clf.predict(train_x)
print('----- Evaluation on Test Data -----')
score_te = clf.score(test_x, test_y)
print('Accuracy Score: ', score_te)
# Look at classification report to evaluate the model
print(classification_report(test_y, y_pred))
print('--------------------------------------------------------')

print('----- Evaluation on Training Data -----')
score_tr = clf.score(train_x, train_y)
print('Accuracy Score: ', score_tr)
# Look at classification report to evaluate the model
print(classification_report(train_y, y_pred_tr))
print('--------------------------------------------------------')
# Out:
# ----- Evaluation on Test Data -----
# Accuracy Score:  0.4806122448979592
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        51
#            5       0.50      0.63      0.56       295
#            6       0.47      0.69      0.56       409
#            7       0.00      0.00      0.00       183
#            8       0.00      0.00      0.00        33
#
#     accuracy                           0.48       980
#    macro avg       0.16      0.22      0.19       980
# weighted avg       0.35      0.48      0.40       980
#
# --------------------------------------------------------
# ----- Evaluation on Training Data -----
# Accuracy Score:  0.5150587034201123
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00        11
#            4       0.00      0.00      0.00       112
# ...

# %%
clf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(train_x, train_y)
 
# performing predictions on the test dataset
y_pred = clf.predict(test_x)
y_pred_tr=clf.predict(train_x)
print('----- Evaluation on Test Data -----')
score_te = clf.score(test_x, test_y)
print('Accuracy Score: ', score_te)
# Look at classification report to evaluate the model
print(classification_report(test_y, y_pred))
print('--------------------------------------------------------')

print('----- Evaluation on Training Data -----')
score_tr = clf.score(train_x, train_y)
print('Accuracy Score: ', score_tr)
# Look at classification report to evaluate the model
print(classification_report(train_y, y_pred_tr))
print('--------------------------------------------------------')
# Out:
# ----- Evaluation on Test Data -----
# Accuracy Score:  0.6571428571428571
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       1.00      0.12      0.21        51
#            5       0.69      0.65      0.67       295
#            6       0.62      0.83      0.71       409
#            7       0.74      0.54      0.62       183
#            8       0.73      0.24      0.36        33
#
#     accuracy                           0.66       980
#    macro avg       0.63      0.40      0.43       980
# weighted avg       0.68      0.66      0.64       980
#
# --------------------------------------------------------
# ----- Evaluation on Training Data -----
# Accuracy Score:  1.0
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00       112
#            5       1.00      1.00      1.00      1162
# ...

# %%
def fitting_linearSVM(X, y, C, gamma):
    # Create training and testing samples
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # Fit the model
    # Note, available kernels: {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
    model = SVC(kernel='linear', probability=True, C=C, gamma=gamma)
    clf = model.fit(X_train, y_train)

    # Predict class labels on training data
    pred_labels_tr = model.predict(X_train)
    # Predict class labels on a test data
    pred_labels_te = model.predict(X_test)

    # Use score method to get accuracy of the model
    print('----- Evaluation on Test Data -----')
    score_te = model.score(X_test, y_test)
    print('Accuracy Score: ', score_te)
    # Look at classification report to evaluate the model
    print(classification_report(y_test, pred_labels_te))
    print('--------------------------------------------------------')

    print('----- Evaluation on Training Data -----')
    score_tr = model.score(X_train, y_train)
    print('Accuracy Score: ', score_tr)
    # Look at classification report to evaluate the model
    print(classification_report(y_train, pred_labels_tr))
    print('--------------------------------------------------------')
    
    # Return relevant data for chart plotting
    return X_train, X_test, y_train, y_test, clf

# %%
X_train, X_test, y_train, y_test, clf = fitting_linearSVM(X,y, 1, 'scale')
# Out:
# ----- Evaluation on Test Data -----
# Accuracy Score:  0.48775510204081635
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        51
#            5       0.54      0.49      0.52       295
#            6       0.47      0.81      0.59       409
#            7       0.00      0.00      0.00       183
#            8       0.00      0.00      0.00        33
#
#     accuracy                           0.49       980
#    macro avg       0.17      0.22      0.19       980
# weighted avg       0.36      0.49      0.40       980
#
# --------------------------------------------------------
# ----- Evaluation on Training Data -----
# ...

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0).fit(X_train, y_train)
clf.fit(train_x, train_y)
 
# performing predictions on the test dataset
y_pred = clf.predict(test_x)
y_pred_tr=clf.predict(train_x)
print('----- Evaluation on Test Data -----')
score_te = clf.score(test_x, test_y)
print('Accuracy Score: ', score_te)
# Look at classification report to evaluate the model
print(classification_report(test_y, y_pred))
print('--------------------------------------------------------')

print('----- Evaluation on Training Data -----')
score_tr = clf.score(train_x, train_y)
print('Accuracy Score: ', score_tr)
# Look at classification report to evaluate the model
print(classification_report(train_y, y_pred_tr))
print('--------------------------------------------------------')
# Out:
# ----- Evaluation on Test Data -----
# Accuracy Score:  0.4846938775510204
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.33      0.27      0.30        51
#            5       0.57      0.52      0.54       295
#            6       0.48      0.63      0.54       409
#            7       0.43      0.28      0.34       183
#            8       0.00      0.00      0.00        33
#
#     accuracy                           0.48       980
#    macro avg       0.30      0.28      0.29       980
# weighted avg       0.47      0.48      0.47       980
#
# --------------------------------------------------------
# ----- Evaluation on Training Data -----
# Accuracy Score:  0.5438999489535478
#               precision    recall  f1-score   support
#
#            3       1.00      0.18      0.31        11
#            4       0.26      0.29      0.27       112
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(train_x, train_y)

# %%
y_pred = clf.predict(test_x)
y_pred_tr=clf.predict(train_x)
print('----- Evaluation on Test Data -----')
score_te = clf.score(test_x, test_y)
print('Accuracy Score: ', score_te)
# Look at classification report to evaluate the model
print(classification_report(test_y, y_pred))
print('--------------------------------------------------------')

print('----- Evaluation on Training Data -----')
score_tr = clf.score(train_x, train_y)
print('Accuracy Score: ', score_tr)
# Look at classification report to evaluate the model
print(classification_report(train_y, y_pred_tr))
print('--------------------------------------------------------')
# Out:
# ----- Evaluation on Test Data -----
# Accuracy Score:  0.4806122448979592
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        51
#            5       0.50      0.63      0.56       295
#            6       0.47      0.69      0.56       409
#            7       0.00      0.00      0.00       183
#            8       0.00      0.00      0.00        33
#
#     accuracy                           0.48       980
#    macro avg       0.16      0.22      0.19       980
# weighted avg       0.35      0.48      0.40       980
#
# --------------------------------------------------------
# ----- Evaluation on Training Data -----
# Accuracy Score:  0.5150587034201123
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00        11
#            4       0.00      0.00      0.00       112
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
#X, y = make_regression(n_features=4, n_informative=2,random_state=0, shuffle=False)
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(train_x, train_y)
y_pred = clf.predict(test_x)
y_pred_tr=clf.predict(train_x)
print('----- Evaluation on Test Data -----')
score_te = clf.score(test_x, test_y)
print('Accuracy Score: ', score_te)
# Look at classification report to evaluate the model
print(classification_report(test_y, y_pred))
print('--------------------------------------------------------')

print('----- Evaluation on Training Data -----')
score_tr = clf.score(train_x, train_y)
print('Accuracy Score: ', score_tr)
# Look at classification report to evaluate the model
print(classification_report(train_y, y_pred_tr))
print('--------------------------------------------------------')
# Out:
# ----- Evaluation on Test Data -----
# Accuracy Score:  0.4806122448979592
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        51
#            5       0.50      0.63      0.56       295
#            6       0.47      0.69      0.56       409
#            7       0.00      0.00      0.00       183
#            8       0.00      0.00      0.00        33
#
#     accuracy                           0.48       980
#    macro avg       0.16      0.22      0.19       980
# weighted avg       0.35      0.48      0.40       980
#
# --------------------------------------------------------
# ----- Evaluation on Training Data -----
# Accuracy Score:  0.5150587034201123
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00        11
#            4       0.00      0.00      0.00       112
# ...

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(train_x,train_y)

print("Score the X-train with Y-train is : ", ridge.score(train_x,train_y))
print("Score the X-test  with Y-test  is : ", ridge.score(test_x,test_y))
# Out:
# Score the X-train with Y-train is :  0.2781657420866216
# Score the X-test  with Y-test  is :  0.24792841273296384

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
#X, y = make_regression(n_features=4, n_informative=2,random_state=0, shuffle=False)
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(train_x, train_y)
print("Score the X-train with Y-train is : ", regr.score(train_x,train_y))
print("Score the X-test  with Y-test  is : ", regr.score(test_x,test_y))
# Out:
# Score the X-train with Y-train is :  0.27748027794649943
# Score the X-test  with Y-test  is :  0.21652545442541604

# %%
from sklearn import linear_model
from sklearn.linear_model import Lasso
clf = linear_model.Lasso(alpha=0.1)
clf.fit(train_x,train_y)

print("Score the X-train with Y-train is : ", clf.score(train_x,train_y))
print("Score the X-test  with Y-test  is : ", clf.score(test_x,test_y))
# Out:
# Score the X-train with Y-train is :  0.2110002711561212
# Score the X-test  with Y-test  is :  0.1684547199210652

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_x, train_y)
reg.fit(train_x,train_y)
print("Score the X-train with Y-train is : ", reg.score(train_x,train_y))
print("Score the X-test  with Y-test  is : ", reg.score(test_x,test_y))
# Out:
# Score the X-train with Y-train is :  0.2879431225101792
# Score the X-test  with Y-test  is :  0.2513476761126239
